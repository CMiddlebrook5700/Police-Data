# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %%
df = pd.read_csv('Police_Department_Incidents_-_Previous_Year__2016_.csv')

# %%
df.head()
# Out:
#    IncidntNum      Category                                        Descript  \
# 0   120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263      WARRANTS                                  WARRANT ARREST
# 3   160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
#
#                   Address           X          Y  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150500 entries, 0 to 150499
# Data columns (total 13 columns):
# IncidntNum    150500 non-null int64
# Category      150500 non-null object
# Descript      150500 non-null object
# DayOfWeek     150500 non-null object
# Date          150500 non-null object
# Time          150500 non-null object
# PdDistrict    150499 non-null object
# Resolution    150500 non-null object
# Address       150500 non-null object
# X             150500 non-null float64
# Y             150500 non-null float64
# Location      150500 non-null object
# PdId          150500 non-null int64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 14.9+ MB

# %%
df.corr()
# Out:
#             IncidntNum         X         Y      PdId
# IncidntNum    1.000000 -0.004190  0.048332  1.000000
# X            -0.004190  1.000000  0.176721 -0.004190
# Y             0.048332  0.176721  1.000000  0.048332
# PdId          1.000000 -0.004190  0.048332  1.000000

# %%
df['Descript'].unique()
# Out:
# array(['POSS OF PROHIBITED WEAPON',
#        'FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE', 'WARRANT ARREST',
#        'LOST PROPERTY', 'BATTERY', 'PAROLE VIOLATION', 'FIRE REPORT',
#        'FOUND PERSON', 'ATTEMPTED THEFT FROM LOCKED VEHICLE',
#        'AIDED CASE, MENTAL DISTURBED', 'RESISTING ARREST',
#        'AGGRAVATED ASSAULT WITH A GUN',
#        'BURGLARY,STORE UNDER CONSTRUCTION, FORCIBLE ENTRY',
#        'STOLEN CHECKS, POSSESSION', 'ROBBERY, ARMED WITH A KNIFE',
#        'BATTERY WITH SERIOUS INJURIES', 'PETTY THEFT SHOPLIFTING',
#        'FRAUDULENT USE OF AUTOMATED TELLER CARD',
#        'POSSESSION OF NARCOTICS PARAPHERNALIA', 'PROBATION VIOLATION',
#        'THREATS AGAINST LIFE', 'VIOLATION OF STAY AWAY ORDER',
#        'LOST/STOLEN LICENSE PLATE', 'BURGLARY, VEHICLE (ARREST MADE)',
#        'TRAFFIC VIOLATION ARREST', 'AIDED CASE', 'STOLEN TRUCK',
#        'STOLEN AUTOMOBILE', 'AGGRAVATED ASSAULT WITH A KNIFE',
# ...

# %%
df['Descript'].nunique()
# Out:
# 726

# %%
df['Descript'].value_counts()
# Out:
# GRAND THEFT FROM LOCKED AUTO                       17741
# LOST PROPERTY                                       4596
# AIDED CASE, MENTAL DISTURBED                        4566
# PETTY THEFT OF PROPERTY                             4416
# MALICIOUS MISCHIEF, VANDALISM                       4262
#                                                    ...
# ATTEMPTED ROBBERY COMM. ESTABLISHMENT W/KNIFE          1
# SAFE BURGLARY OF A HOTEL                               1
# BURGLARY,WAREHOUSE UNDER CONSTRT, ATT. FORCIBLE        1
# VIN SWITCH                                             1
# SALE OF ALCOHOL AFTER HOURS                            1
# Name: Descript, Length: 726, dtype: int64

# %%
df = df.drop('X',axis=1)

# %%
df = df.drop('Y',axis=1)

# %%
df.head(3)
# Out:
#    IncidntNum     Category                                        Descript  \
# 0   120058272  WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272  WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263     WARRANTS                                  WARRANT ARREST
#
#   DayOfWeek                    Date   Time PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00   SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00   SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59    BAYVIEW  ARREST, BOOKED
#
#                   Address                               Location  \
# 0  800 Block of BRYANT ST   (37.775420706711, -122.403404791479)
# 1  800 Block of BRYANT ST   (37.775420706711, -122.403404791479)
# 2   KEITH ST / SHAFTER AV  (37.7299809672996, -122.388856204292)
#
#              PdId
# 0  12005827212120
# 1  12005827212168
# 2  14105926363010

# %%
df['DayOfWeek'].value_counts()
# Out:
# Friday       23371
# Saturday     22172
# Thursday     21395
# Wednesday    21332
# Tuesday      21242
# Monday       20783
# Sunday       20205
# Name: DayOfWeek, dtype: int64

# %%
df['PdDistrict'].value_counts()
# Out:
# SOUTHERN      28445
# NORTHERN      20100
# MISSION       19503
# CENTRAL       17666
# BAYVIEW       14303
# INGLESIDE     11594
# TARAVAL       11325
# TENDERLOIN     9942
# RICHMOND       8922
# PARK           8699
# Name: PdDistrict, dtype: int64

# %%
df['Category'].value_counts().head()
# Out:
# LARCENY/THEFT     40409
# OTHER OFFENSES    19599
# NON-CRIMINAL      17866
# ASSAULT           13577
# VANDALISM          8589
# Name: Category, dtype: int64

# %%
df.head(5)
# Out:
#    IncidntNum      Category                                        Descript  \
# 0   120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263      WARRANTS                                  WARRANT ARREST
# 3   160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
#
#                   Address                               Location  \
# ...

# %%
df[df['Descript'] == 'FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE'][df['PdDistrict'] == 'SOUTHERN']
# Out:
# C:\Users\CMiddlebrook\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         IncidntNum     Category  \
# 1        120058272  WEAPON LAWS
# 3572     160176668  WEAPON LAWS
# 38204    160243449  WEAPON LAWS
# 45405    160214876  WEAPON LAWS
# 59270    160606546  WEAPON LAWS
# 61933    160629623  WEAPON LAWS
# 67950    160243938  WEAPON LAWS
# 70201    160701873  WEAPON LAWS
# 79255    160780065  WEAPON LAWS
# 86374    160844940  WEAPON LAWS
# 96900    160935555  WEAPON LAWS
# 139229   160040085  WEAPON LAWS
# 141078   160307211  WEAPON LAWS
#
#                                               Descript  DayOfWeek  \
# 1       FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE     Friday
# 3572    FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE     Monday
# 38204   FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE  Wednesday
# ...

# %%
df[df['Descript'] == 'MASSAGE ESTABLISHMENT PERMIT VIOLATION']['DayOfWeek'].value_counts()
# Out:
# Friday       11
# Wednesday     5
# Tuesday       5
# Thursday      4
# Name: DayOfWeek, dtype: int64

# %%
df['Date'].value_counts()
# Out:
# 01/01/2016 12:00:00 AM    558
# 10/08/2016 12:00:00 AM    532
# 04/01/2016 12:00:00 AM    525
# 01/29/2016 12:00:00 AM    514
# 12/14/2016 12:00:00 AM    507
#                          ...
# 06/06/2016 12:00:00 AM    326
# 11/24/2016 12:00:00 AM    319
# 01/03/2016 12:00:00 AM    316
# 03/13/2016 12:00:00 AM    304
# 12/25/2016 12:00:00 AM    226
# Name: Date, Length: 366, dtype: int64

# %%
df[df['Date'] == '01/01/2016 12:00:00 AM'][df['PdDistrict'] == 'NORTHERN']
# Out:
# C:\Users\CMiddlebrook\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         IncidntNum        Category  \
# 5        160002869         ASSAULT
# 152      160000647     DRUNKENNESS
# 886      160049708    NON-CRIMINAL
# 2803     160000528         ASSAULT
# 2804     160000528     DRUNKENNESS
# ...            ...             ...
# 115965   160008566    NON-CRIMINAL
# 139346   170198408  OTHER OFFENSES
# 141388   160003447    NON-CRIMINAL
# 142822   160029465  SUSPICIOUS OCC
# 150040   160001758    NON-CRIMINAL
#
#                                               Descript DayOfWeek  \
# 5                                              BATTERY    Friday
# 152       UNDER INFLUENCE OF ALCOHOL IN A PUBLIC PLACE    Friday
# 886                                      LOST PROPERTY    Friday
# ...

# %%
df['PdDistrict'][df['Resolution'] == 'ARREST, BOOKED'].value_counts()
# Out:
# SOUTHERN      8086
# MISSION       6531
# NORTHERN      4352
# TENDERLOIN    4252
# BAYVIEW       3890
# CENTRAL       3572
# INGLESIDE     2755
# TARAVAL       2616
# PARK          1949
# RICHMOND      1413
# Name: PdDistrict, dtype: int64
